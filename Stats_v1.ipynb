# %%
import numpy as np
a = [10,15,16,21,22,25,26,31,32,33,34,35,36,37,38, 44,46,48,49,50,55,60]

# %%
import scipy
from scipy import stats
stats.describe(a)
# Out:
# DescribeResult(nobs=22, minmax=(10, 60), mean=34.68181818181818, variance=180.512987012987, skewness=0.008082267643488399, kurtosis=-0.7761502378807292)

# %%
np.var(a)
# Out:
# 172.30785123966942

# %%
np.std(a)
# Out:
# 13.126608520088858

# %%
np.mean(a)
# Out:
# 34.68181818181818

# %%
import matplotlib.pyplot as plt
plt.hist(a) 
plt.title("histogram") 
plt.show()

# %%
import pandas as pd
pd.Series(a).plot(kind='density')

# %%
### plot with normal distribution
from scipy.stats import norm
##mean = 34.6 , sd = 13.4
plt.plot(a, norm.pdf(a,34.6,13.4))
plt.show()

# %%
### propability of <=x  
norm.cdf(50,34.6,13.4)
# Out:
# 0.8747743146292283

# %%
### probability of having a salary of atleast 30L when mean is 25L and Sd = 5L 
norm.cdf(3000000,2500000,500000)
# Out:
# 0.8413447460685429

# %%
norm.cdf(26, 25, 5)
# Out:
# 0.579259709439103

# %%
### probability( Percentage of emp) having a salary b/w 32L and 30 L 
norm.cdf(3200000,2500000,500000)-norm.cdf(3000000,2500000,500000)
# Out:
# 0.07789859469768601

# %%
norm.cdf(26, 25, 5) - norm.cdf(25, 25, 5)
# Out:
# 0.07925970943910299

# %%
# ?.cdf
# Out:
# Object `.cdf` not found.

# %%
### probability( Percentage of emp) having a salary b/w 30L and 25 L 
norm.cdf(3000000,2500000,500000)-norm.cdf(2500000,2500000,500000)
# Out:
# 0.3413447460685429

# %%
### propability of having a salary of gt 40L 
1-norm.cdf(4000000,2500000,500000)
# Out:
# 0.0013498980316301035

# %%
#### qnorm is the opposite of pnorm which is ppf #q1
norm.ppf(0.25, 2500000,  500000)
# Out:
# 2162755.124901959

# %%
norm.ppf(0.75, 2500000,  500000)
# Out:
# 2837244.875098041

# %%
norm.ppf(0.5, 2500000,  500000)
# Out:
# 2500000.0

# %%
norm.ppf(0.95, 2500000,  500000)
# Out:
# 3322426.813475736

# %%
norm.ppf(0.997, 2500000,  500000)
# Out:
# 3873890.6927224966

# %%
### zscores using scale function 
stats.zscore(a)
# Out:
# array([-1.88028904, -1.49938334, -1.4232022 , -1.0422965 , -0.96611537,
#        -0.73757195, -0.66139081, -0.28048511, -0.20430397, -0.12812283,
#        -0.05194169,  0.02423945,  0.10042059,  0.17660173,  0.25278287,
#         0.70986971,  0.86223199,  1.01459427,  1.09077541,  1.16695655,
#         1.54786225,  1.92876795])

# %%
b=stats.zscore(a)
np.mean(b)
# Out:
# 1.8167285857502563e-16

# %%
np.std(b)
# Out:
# 1.0

# %%
girls =[7, 8, 9, 9, 6, 7, 8, 4, 5, 4, 7, 5, 5, 5, 9, 4,9,5,7, 9,9,9,9,9,9,9]
len(girls)
# Out:
# 26

# %%
boys = [5,6,7,5,6,7,8,4,9,6,5,7,8,6,7,5,8,4,4,8 ,3,4,3,4,3,4]
len(boys)
# Out:
# 26

# %%
np.mean(girls)
# Out:
# 7.153846153846154

# %%
np.mean(boys)
# Out:
# 5.615384615384615

# %%
#stats.ttest_1samp(girls,boys)

# %%
# one-tailed, greater than 'boys'
stats.ttest_rel(girls,boys)
# Out:
# Ttest_relResult(statistic=2.743073910242014, pvalue=0.011091658408932612)

# %%
##H0  equal population varience
## h0 : girls(mean) == boys(mean)
## ha : girls(mean) != boys(mean)
stats.ttest_ind(girls,boys)
# Out:
# Ttest_indResult(statistic=2.9774566708770696, pvalue=0.004472428811923714)

# %%
##H0 not equal
stats.ttest_ind(girls,boys,equal_var = False)
# Out:
# Ttest_indResult(statistic=2.9774566708770696, pvalue=0.004482529889169198)

# %%
stats.ttest_1samp(girls,6)
# Out:
# Ttest_1sampResult(statistic=3.0441560942557473, pvalue=0.005429031565595666)

# %%
stats.ttest_1samp(boys,6)
# Out:
# Ttest_1sampResult(statistic=-1.0952698858458099, pvalue=0.2838383781749628)

# %%
norm.rvs(100, 1000, 1)
# Out:
# array([-496.22392411])

# %%
c= np.random.normal(1000,1, 100)

# %%
stats.ttest_1samp(c,1000)
# Out:
# Ttest_1sampResult(statistic=-0.0123309066495184, pvalue=0.990186424456257)

# %%
x=[1,2,3,4,5]
y=[55, 44, 39, 21, 15]

# %%
plt.plot(x,y)
plt.show()

# %%
np.corrcoef(x,y)
# Out:
# array([[ 1.        , -0.98529637],
#        [-0.98529637,  1.        ]])

# %%
z=[55, 44, 39, 21, 15]
np.corrcoef(x,z)

# %%
plt.plot(x,z)
plt.show()

# %%
import os
## reading data
import pandas as pd
credit=pd.read_csv("D:\AP\Dtrees\credit.csv")

# %%
credit.describe()
# Out:
#        months_loan_duration        amount  percent_of_income  \
# count           1000.000000   1000.000000        1000.000000
# mean              20.903000   3271.258000           2.973000
# std               12.058814   2822.736876           1.118715
# min                4.000000    250.000000           1.000000
# 25%               12.000000   1365.500000           2.000000
# 50%               18.000000   2319.500000           3.000000
# 75%               24.000000   3972.250000           4.000000
# max               72.000000  18424.000000           4.000000
#
#        years_at_residence          age  existing_loans_count   dependents
# count         1000.000000  1000.000000           1000.000000  1000.000000
# mean             2.845000    35.546000              1.407000     1.155000
# std              1.103718    11.375469              0.577654     0.362086
# min              1.000000    19.000000              1.000000     1.000000
# ...

# %%
credit.head(10)
# Out:
#   checking_balance  months_loan_duration credit_history               purpose  \
# 0           < 0 DM                     6       critical  furniture/appliances
# 1       1 - 200 DM                    48           good  furniture/appliances
# 2          unknown                    12       critical             education
# 3           < 0 DM                    42           good  furniture/appliances
# 4           < 0 DM                    24           poor                   car
# 5          unknown                    36           good             education
# 6          unknown                    24           good  furniture/appliances
# 7       1 - 200 DM                    36           good                   car
# 8          unknown                    12           good  furniture/appliances
# 9       1 - 200 DM                    30       critical                   car
#
#    amount savings_balance employment_duration  percent_of_income  \
# ...

# %%
pd.crosstab(credit.default,credit.phone)
# Out:
# phone     no  yes
# default
# no       409  291
# yes      187  113

# %%
113/(113+291)
# Out:
# 0.27970297029702973

# %%
187/(187+409)
# Out:
# 0.313758389261745

# %%
0.2797/0.3137
# Out:
# 0.8916161938157476

# %%
1/0.892
# Out:
# 1.1210762331838564

# %%
chi_1 = pd.crosstab(credit.default,credit.phone)

# %%
scipy.stats.chi2_contingency(chi_1)
# Out:
# (1.1725585310208855, 0.27887615430357426, 1, array([[417.2, 282.8],
#         [178.8, 121.2]]))

# %%
 a= [24, 26, 31, 27, 8]
 b =[29, 31,30, 36,33]
 c = [29, 27, 34, 26, 23]
 d = {'a':a,'b':b,'c':c}

# %%
df = pd.DataFrame(d)

# %%
fvalue, pvalue = stats.f_oneway(d['a'], d['b'], d['c'])
print(fvalue, pvalue)
# Out:
# 2.6944713870029084 0.10800613044872108

# %%
df.columns
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
# get ANOVA table as R like output
import statsmodels.api as sm
from statsmodels.formula.api import ols
model = ols('c ~ a+b', data=df).fit()
anova_table = sm.stats.anova_lm(model)
anova_table
# Out:
#            df     sum_sq    mean_sq         F    PR(>F)
# a         1.0  40.705972  40.705972  6.321885  0.128410
# b         1.0  13.216232  13.216232  2.052561  0.288322
# Residual  2.0  12.877796   6.438898       NaN       NaN

# %%
anova_table.describe()
# Out:
#              df     sum_sq    mean_sq         F    PR(>F)
# count  3.000000   3.000000   3.000000  2.000000  2.000000
# mean   1.333333  22.266667  20.120367  4.187223  0.208366
# std    0.577350  15.969803  18.146857  3.018868  0.113075
# min    1.000000  12.877796   6.438898  2.052561  0.128410
# 25%    1.000000  13.047014   9.827565  3.119892  0.168388
# 50%    1.000000  13.216232  13.216232  4.187223  0.208366
# 75%    1.500000  26.961102  26.961102  5.254554  0.248344
# max    2.000000  40.705972  40.705972  6.321885  0.288322

# %%
from sklearn import linear_model
lm = linear_model.LinearRegression()
X=df[['a','b']]
y=df['c']
model1 = lm.fit(X,y)

# %%
model1.intercept_
# Out:
# 41.79644183435529

# %%
model1.coef_
# Out:
# array([ 0.3153122 , -0.67017877])

# %%
# Out:
# <bound method RegressorMixin.score of LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)>
